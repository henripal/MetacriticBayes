# %%
from bs4 import BeautifulSoup
import urllib.request
import time
import sys
import random
from string import ascii_lowercase
import pickle

# %%
LETTERS = '#' + ascii_lowercase
BASE_URL = 'http://www.metacritic.com/browse/movies/title/dvd'

# %%
def make_soup_from_url(url, attempt=0):
    attempt = attempt + 1
    time.sleep(int(random.random()*20))
    if attempt > 10:
        return None
    try:
        req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
        html = urllib.request.urlopen(req).read()
        return BeautifulSoup(html, "lxml")
    except:
        make_soup_from_url(url, attempt)

# %%
def make_soup(letter, page, attempt = 0):
    if letter == '#':
        url = BASE_URL + "?page=" + str(page)
    else:
        url = BASE_URL + "/" + letter + "?page=" + str(page)

# %%
movie_list = []

# %%
for letter in LETTERS:
    print('processing letter: ' + letter + ' ...')
    page = 0
    while True:
        soup = make_soup(letter, page)
        
        if soup:
            results = soup.find_all('tr', {'class': 'summary_row'})
            links = [result.find('td', {'class': 'title_wrapper'}).find('a')['href'] for result in results]
        else:
            links = []
        
        movie_list = movie_list + links
        
        if links:
            page = page + 1
        else:
            break

# %%
with open('../data/movielist_mc', 'wb') as f:
    pickle.dump(movie_list, f)

# %% [markdown]
# ## Scraping individual pages

# %%
sys.path.append('../src/')

# %%
INDIV_URL = 'http://www.metacritic.com'
TR_FIELDS = ['runtime', 'movie_rating', 'company'] 
MULTI_TR_FIELDS = ['languages', 'countries', 'genres']
import csv
import Movies
import pandas as pd

# %%
with open('../data/movielist_mc', 'rb') as f:
    movie_list = pickle.load(f)

# %%
# oh, lisp, where art thou
def get_name(v):
    return [ k for k,v in locals().iteritems() if v is blah][0]

# %%
def my_write(name, index):
    with open('../data/' + name + str(index) + '.csv', 'w') as f:
        csv_writer = csv.writer(f)
        csv_writer.writerows(eval(name))

# %%
def my_read(name, index):
    result = []
    with open('../data/' + name + str(index) + '.csv', 'r') as f:
        csv_reader = csv.reader(f)
        for row in csv_reader:
            result.append(row)
    return result

# %%
def my_append(url_id, array, iterable):
    try:
        if isinstance(iterable, str):
            array.append([url_id, iterable])
        else:
            for item in iterable:
                array.append([url_id, item])
    except:
        pass

# %%
basics =[]
languages = []
countries =[]
genres = []
cast = []
director = []
producer =[]
writer = []
reviews = []

table_list = ['basics', 'languages', 'countries', 'genres', 'cast', 'director', 'producer', 'writer', 'reviews']

print('starting...')
start_at = 8254

for index, movie in enumerate(movie_list):
    if index < start_at:
        # don't do anything
        continue
    elif index == start_at:
        # load csvs
        for name in table_list:
            exec(name + '= my_read(\'' + name + '\', 1001)')
        continue
    
    if index%5 == 1:
        print('Finished ' + str(index) + ' out of ' + str(len(movie_list)))
        for name in table_list:
            my_write(name, 1001)
        
        
            
    url_id = movie[7:] 
    print(url_id, end ='\r')
    scraped = Movies.Movie(url_id)
    basics.append([url_id, 
             scraped.title, scraped.metascore, scraped.user_score,
             scraped.release_date, scraped.runtime, scraped.movie_rating,
             scraped.company, scraped.user_reviews[0], scraped.user_reviews[1],
            scraped.user_reviews[2]])
    
    my_append(url_id, languages, scraped.languages)
    my_append(url_id, countries, scraped.countries)
    my_append(url_id, genres, scraped.genres)
    my_append(url_id, cast, scraped.cast)
    my_append(url_id, director, scraped.director)
    my_append(url_id, producer, scraped.producer)
    my_append(url_id, writer, scraped.writer)
    
    reviews = reviews + [list((url_id,) + review) for review in scraped.reviews]
# Out:
# starting...
# Finished 8256 out of 8445
# Finished 8261 out of 8445
# Finished 8266 out of 8445elf
# Finished 8271 out of 8445
# Finished 8276 out of 8445
# Finished 8281 out of 8445days-30-nights---hollywood-to-the-heartland
# Finished 8286 out of 8445real-world
# Finished 8291 out of 8445-never-be-the-same
# Finished 8296 out of 8445
# Finished 8301 out of 8445
# Finished 8306 out of 8445
# Finished 8311 out of 8445ge-w-bush-and-the-rise-of-the-religious-right-in-america
# Finished 8316 out of 8445tion
# Finished 8321 out of 8445
# Finished 8326 out of 8445n
# Finished 8331 out of 8445ervous-breakdown
# Finished 8336 out of 8445
# Finished 8341 out of 8445
# Finished 8346 out of 8445
# Finished 8351 out of 8445
# Finished 8356 out of 84453
# Finished 8361 out of 8445
# Finished 8366 out of 8445
# Finished 8371 out of 8445rkswar-of-the-underworld
# Finished 8376 out of 8445
# Finished 8381 out of 8445
# Finished 8386 out of 8445
# Finished 8391 out of 8445-stranger
# Finished 8396 out of 8445
# Finished 8401 out of 8445
# Finished 8406 out of 8445t-i-love
# Finished 8411 out of 8445
# Finished 8416 out of 8445osessionau-75116-paris
# Finished 8421 out of 8445
# Finished 8426 out of 8445
# Finished 8431 out of 8445iders-from-mars
# Finished 8436 out of 8445
# Finished 8441 out of 8445
# zus-zoia6

# %%
for name in table_list:
    my_write(name, 1001)

# %%
url_id
# Out:
# 'whos-your-caddy'

# %%
scraped = Movies.Movie(url_id)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
# ---> 45             html = urllib.request.urlopen(req).read()
#      46             return BeautifulSoup(html, "lxml")
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 404: Not Found
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      43         try:
# ---> 44             req = urllib.request.Request(url, headers={'User-Agent': 'chrome'})
#      45             html = urllib.request.urlopen(req).read()
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     328                  method=None):
# --> 329         self.full_url = url
#     330         self.headers = {}
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in full_url(self, url)
#     354         self._full_url, self.fragment = splittag(self._full_url)
# --> 355         self._parse()
#     356
#
# /home/henripal/anaconda3/lib/python3.6/urllib/request.py in _parse(self)
#     383         if self.type is None:
# --> 384             raise ValueError("unknown url type: %r" % self.full_url)
#     385         self.host, self.selector = splithost(rest)
#
# ValueError: unknown url type: '1'
#
# ...
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      46             return BeautifulSoup(html, "lxml")
#      47         except:
# ---> 48             self.make_soup_from_url(attempt)
#      49
#      50     def get_tr(self, search_string):
#
# /home/henripal/projects/movies/src/Movies.py in make_soup_from_url(self, url, attempt)
#      38     def make_soup_from_url(self, url, attempt=0):
#      39         attempt = attempt + 1
# ---> 40         time.sleep(SLEEP_TIME + attempt*int(random.random()))
#      41         if attempt > 10:
#      42             return None
#
# KeyboardInterrupt:

# %%
index
# Out:
# 8254

# %%
movie_list[index]
# Out:
# '/movie/who-the--is-jackson-pollock'

# %%
languages

# %%
countries

# %%
reviews

# %%
import importlib
importlib.reload(Movies)

# %%
ha.director

# %%
movie_list[0][7:]

# %%
a = (1, 2)

# %%
(1,) + a

# %%
for i in range(5):
    time.sleep(1)
    print("hi " + str(i),end='\r')
# Out:
# hi 4

# %%
range(5)
# Out:
# range(0, 5)
